# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("mobile_price_data.csv")

# %%
df1.head()
# Out:
#                             mobile_name mobile_price mobile_color  dual_sim  \
# 0    Realme Narzo 10A (So White, 32 GB)       ₹8,999     So White  Dual Sim
# 1     Realme Narzo 10A (So Blue, 32 GB)       ₹8,999      So Blue  Dual Sim
# 2     Realme Narzo 10A (So Blue, 64 GB)       ₹9,999      So Blue  Dual Sim
# 3    Realme Narzo 10A (So White, 64 GB)       ₹9,999     So White  Dual Sim
# 4  Realme Narzo 10 (That Green, 128 GB)      ₹11,999   That Green  Dual Sim
#
#               disp_size         resolution          os  num_cores mp_speed  \
# 0  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 1  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 2  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 3  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 4   16.51 cm (6.5 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
#
#   int_memory   ram                   p_cam              f_cam  \
# 0      32 GB  3 GB        12MP + 2MP + 2MP   5MP Front Camera
# 1      32 GB  3 GB        12MP + 2MP + 2MP   5MP Front Camera
# 2      64 GB  4 GB        12MP + 2MP + 2MP   5MP Front Camera
# 3      64 GB  4 GB        12MP + 2MP + 2MP   5MP Front Camera
# 4     128 GB  4 GB  48MP + 8MP + 2MP + 2MP  16MP Front Camera
#
#                 network bluetooth battery_power mob_width mob_height  \
# 0  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 1  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 2  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 3  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 4  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh   75.4 mm   164.4 mm
#
#   mob_depth mob_weight
# 0   8.95 mm      195 g
# 1   8.95 mm      195 g
# 2   8.95 mm      195 g
# 3   8.95 mm      195 g
# 4      9 mm      199 g

# %%
df = df1.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    459 non-null    object
#  1   mobile_price   459 non-null    object
#  2   mobile_color   459 non-null    object
#  3   dual_sim       459 non-null    object
#  4   disp_size      459 non-null    object
#  5   resolution     459 non-null    object
#  6   os             459 non-null    object
#  7   num_cores      459 non-null    object
#  8   mp_speed       459 non-null    object
#  9   int_memory     459 non-null    object
#  10  ram            459 non-null    object
#  11  p_cam          459 non-null    object
#  12  f_cam          459 non-null    object
#  13  network        459 non-null    object
#  14  bluetooth      459 non-null    object
#  15  battery_power  459 non-null    object
#  16  mob_width      459 non-null    object
#  17  mob_height     459 non-null    object
#  18  mob_depth      459 non-null    object
#  19  mob_weight     459 non-null    object
# dtypes: object(20)
# memory usage: 71.8+ KB

# %%
#first lets clean the target column i.e: mobile_price
df["mobile_price"] = df["mobile_price"].str.replace("₹","")
df["mobile_price"] = df["mobile_price"].str.replace(",","")

# %%
#checking the columns by taking random 3 data 
df["mobile_price"].sample(3)
# Out:
# 425    31590
# 147    17999
# 156     8499
# Name: mobile_price, dtype: object

# %%
df.columns
# Out:
# Index(['mobile_name', 'mobile_price', 'mobile_color', 'dual_sim', 'disp_size',
#        'resolution', 'os', 'num_cores', 'mp_speed', 'int_memory', 'ram',
#        'p_cam', 'f_cam', 'network', 'bluetooth', 'battery_power', 'mob_width',
#        'mob_height', 'mob_depth', 'mob_weight'],
#       dtype='object')

# %%
#lets make a list of features that seems to have categorical data
l = ['mobile_color', 'dual_sim', 'disp_size', 'os', 'num_cores', 'mp_speed', 'int_memory', 'ram','p_cam', 'f_cam', 'network', 'bluetooth']

# %%
for v in l:
    print(f"{v}:")
    print(f"{df[v].value_counts()}")
    print("____________________________________")
# Out:
# mobile_color:
# Black              28
# Red                20
# Gold               19
# Blue               14
# Rose Gold          10
#                    ..
# Emerald Green       1
# Forest Green        1
# Charcoal Blue       1
# Moonlight White     1
# Twilight Purple     1
# Name: mobile_color, Length: 165, dtype: int64
# ____________________________________
# dual_sim:
# Dual Sim      458
# Single Sim      1
# Name: dual_sim, dtype: int64
# ____________________________________
# disp_size:
# 16.51 cm (6.5 inch)      51
# 15.8 cm (6.22 inch)      50
# 16.0 cm (6.3 inch)       38
# 15.21 cm (5.99 inch)     35
# 16.94 cm (6.67 inch)     33
# 16.26 cm (6.4 inch)      24
# 16.59 cm (6.53 inch)     21
# 15.75 cm (6.2 inch)      21
# 16.23 cm (6.39 inch)     17
# 16.13 cm (6.35 inch)     14
# 16.76 cm (6.6 inch)      14
# 16.21 cm (6.38 inch)     12
# 13.97 cm (5.5 inch)      12
# 15.7 cm (6.18 inch)      11
# 15.49 cm (6.1 inch)      11
# 16.36 cm (6.44 inch)     11
# 14.48 cm (5.7 inch)      10
# 16.56 cm (6.52 inch)      8
# 14.35 cm (5.65 inch)      7
# 16.69 cm (6.57 inch)      7
# 15.9 cm (6.26 inch)       7
# 15.24 cm (6 inch)         6
# 13.84 cm (5.45 inch)      5
# 12.7 cm (5 inch)          4
# 16.28 cm (6.41 inch)      4
# 13.21 cm (5.2 inch)       3
# 15.77 cm (6.21 inch)      3
# 15.46 cm (6.088 inch)     3
# 15.19 cm (5.98 inch)      3
# 15.44 cm (6.08 inch)      3
# 15.72 cm (6.19 inch)      3
# 15.82 cm (6.23 inch)      2
# 15.06 cm (5.93 inch)      2
# 17.02 cm (6.7 inch)       2
# 16.74 cm (6.59 inch)      1
# 11.94 cm (4.7 inch)       1
# Name: disp_size, dtype: int64
# ____________________________________
# os:
# Android Pie 9                126
# Android Oreo 8.1              96
# Android Pie 9.0               82
# Android 10                    68
# Android Pie 10                16
# Android Nougat 7.1.2          14
# Android Oreo 8.1.0            13
# Android Nougat 7.1            12
# Android Oreo 8                 7
# Android Nougat 7               7
# Android Oreo 8.0               6
# Android Lollipop 5.1           3
# Android Marshmallow 6          3
# Android Marshmallow 6.0.1      2
# Android Lollipop 5.4.1         1
# Android KitKat 4.4.2           1
# Android Nougat 7.1.1           1
# Android Lollipop 5.1.1         1
# Name: os, dtype: int64
# ____________________________________
# num_cores:
# Octa Core      444
# Quad Core       14
# Single Core      1
# Name: num_cores, dtype: int64
# ____________________________________
# mp_speed:
# 2 GHz        149
# 2.3 GHz       65
# 1.8 GHz       52
# 2.2 GHz       52
# 1.4 GHz       24
# 2.1 GHz       22
# 1.95 GHz      20
# 2.8 GHz       20
# 2.96 GHz      19
# 2.84 GHz      11
# 2.5 GHz        7
# 2.05 GHz       3
# 1.5 GHz        3
# 1.6 GHz        3
# 2.39 GHz       3
# 2.6 GHz        3
# 2.649 GHz      2
# 1.3 GHz        1
# Name: mp_speed, dtype: int64
# ____________________________________
# int_memory:
# 64 GB     185
# 128 GB    126
# 32 GB      91
# 256 GB     30
# 16 GB      24
# 512 GB      2
# 8 GB        1
# Name: int_memory, dtype: int64
# ____________________________________
# ram:
# 4 GB     160
# 6 GB     110
# 3 GB      73
# 8 GB      67
# 2 GB      36
# 12 GB      9
# 1 GB       4
# Name: ram, dtype: int64
# ____________________________________
# p_cam:
# 13MP + 2MP                                                                                      72
# 13MP Rear Camera                                                                                45
# 48MP + 8MP + 2MP + 2MP                                                                          39
# 12MP + 5MP                                                                                      38
# 64MP + 8MP + 2MP + 2MP                                                                          22
# 48MP + 5MP                                                                                      21
# 48MP + 13MP + 8MP                                                                               17
# 48MP + 8MP + 5MP + 2MP                                                                          16
# 64MP + 13MP + 8MP + 2MP                                                                         15
# 12MP + 2MP                                                                                      12
# 12MP Rear Camera                                                                                11
# 16MP + 2MP                                                                                      10
# 48MP + 8MP + 2MP                                                                                10
# 16MP + 2MP + 8MP                                                                                 9
# 20MP + 12MP                                                                                      9
# 16MP Rear Camera                                                                                 9
# 13MP + 8MP + 2MP                                                                                 9
# 12MP + 2MP + 2MP                                                                                 8
# 64MP + 12MP + 8MP + 2MP                                                                          8
# 16MP + 8MP + 2MP                                                                                 6
# 48MP + 8MP                                                                                       6
# 8MP Rear Camera                                                                                  6
# 48MP + 8MP + 2MP + 2MP Quad Camera                                                               6
# 64MP + 8MP + 8MP + 2MP                                                                           4
# 108MP Rear Camera                                                                                4
# 13MP + 2MP Depth Sensor + 8MP Wide Angle sensor                                                  3
# 12MP + 13MP                                                                                      3
# 16MP + 2MP + Low Light Sensor                                                                    3
# 13MP + 2MP + 8MP                                                                                 3
# 12MP + 8MP + 2MP + 2MP                                                                           2
# 16MP + 5MP + 2MP + Low Light Sensor                                                              2
# 48MP + 12MP + 5MP                                                                                2
# 48MP + 2MP + Low Light Sensor                                                                    2
# 16MP + 20MP                                                                                      2
# 13 MP + 2 MP + 2 MP + Low Light Sensor                                                           2
# 48 MP + 2 MP + 2 MP + Low Light Sensor                                                           2
# 16MP + 5MP                                                                                       2
# 48MP + 8MP + 5MP                                                                                 2
# 48MP + 13MP + 8MP + 2MP                                                                          2
# 48 Million Quad Pixel Sensor (12 Million Effective Pixel) + 8MP + 5MP, AI Triple Rear Camera     2
# 64MP + 8MP + 2MP + 2MP Quad Camera                                                               2
# 13MP + 8MP + 2MP + 2MP                                                                           2
# 64MP + 8MP + 5MP + 2MP                                                                           2
# 12MP + 20MP                                                                                      2
# 5MP Rear Camera                                                                                  1
# 64MP + 8MP + 5MP + 5MP                                                                           1
# 12MP + 5MP + 8MP                                                                                 1
# 48MP + 5MP + 8MP                                                                                 1
# 48MP + 8MP + 13MP + 2MP                                                                          1
# Name: p_cam, dtype: int64
# ____________________________________
# f_cam:
# 16MP Front Camera               112
# 8MP Front Camera                 65
# 20MP Front Camera                61
# 5MP Front Camera                 54
# 32MP Front Camera                53
# 13MP Front Camera                45
# 20MP + 2MP Dual Front Camera     16
# 32MP + 8MP Dual Front Camera     13
# 25MP Front Camera                13
# 24MP Front Camera                 7
# 16MP + 8MP Dual Front Camera      6
# 8MP Dual Front Camera             6
# 13MP + 2MP Dual Front Camera      3
# 44MP + 2MP Dual Front Camera      3
# 2MP Front Camera                  2
# Name: f_cam, dtype: int64
# ____________________________________
# network:
# 3G, 4G VOLTE, 4G, 2G        139
# 3G, 4G VOLTE, 2G             85
# 4G VOLTE, 4G, 3G, 2G         79
# 3G, 4G, 2G                   39
# 4G, 3G, 2G                   26
# 4G VOLTE, 4G, 2G, 3G         20
# 4G VOLTE, 3G, 2G             14
# 3G, 4G VOLTE, 4G             13
# 4G VOLTE, 3G                 10
# 4G VOLTE                      8
# 3G, 4G VOLTE                  8
# 4G VOLTE, 5G                  4
# 5G, 4G VOLTE, 4G, 3G, 2G      3
# 4G, 2G, 3G                    3
# 4G VOLTE, 4G                  3
# 2G                            2
# 3G, 4G                        2
# 3G                            1
# Name: network, dtype: int64
# ____________________________________
# bluetooth:
# Yes    459
# Name: bluetooth, dtype: int64
# ____________________________________

# %%
df.shape
# Out:
# (459, 20)

# %%
#blutooth columns has only one data so lets drop it
df.drop("bluetooth",axis = 1,inplace = True)

# %%
#as we can see from the count that there is a single sim phone so lets check that out 
df[df["dual_sim"] == "Single Sim"]
# Out:
#                     mobile_name mobile_price   mobile_color    dual_sim  \
# 108  MI3 (Metallic Grey, 16 GB)        13999  Metallic Grey  Single Sim
#
#             disp_size          resolution                    os  num_cores  \
# 108  12.7 cm (5 inch)  1920 x 1080 Pixels  Android KitKat 4.4.2  Quad Core
#
#     mp_speed int_memory   ram             p_cam             f_cam network  \
# 108  2.3 GHz      16 GB  2 GB  13MP Rear Camera  2MP Front Camera      3G
#
#     battery_power mob_width mob_height mob_depth mob_weight
# 108      3050 mAh   73.6 mm     144 mm    8.1 mm      145 g

# %%
# droping the dual_sim columns as it will not play any significant role in predicting the price.
df.drop("dual_sim",axis= 1,inplace= True)

# %%
#check the shape of the dataframe after deleting the bluetooth and dual sim columns
df.shape
# Out:
# (459, 18)

# %%
#check the shape of the dataframe after deleting the bluetooth and dual sim columns
df.shape
(459, 18)
#from our value counts we can see that there is a mobile with ram 1gb so lets check that out
# for more specifications
df[df["ram"] == "1 GB"]
# Out:
#                                       mobile_name mobile_price   mobile_color  \
# 149                        Redmi Go (Blue, 16 GB)         6700           Blue
# 177                        Redmi Go (Blue, 16 GB)         6700           Blue
# 298         Samsung Galaxy J2 Core (Black, 16 GB)         6299          Black
# 302  Samsung Galaxy J2-2017 (Metallic gold, 8 GB)         6000  Metallic gold
#
#                disp_size         resolution                      os  \
# 149     12.7 cm (5 inch)  1280 x 720 pixels        Android Oreo 8.1
# 177     12.7 cm (5 inch)  1280 x 720 pixels        Android Oreo 8.1
# 298     12.7 cm (5 inch)   960 x 540 Pixels        Android Oreo 8.1
# 302  11.94 cm (4.7 inch)   540 x 960 Pixels  Android Lollipop 5.4.1
#
#      num_cores mp_speed int_memory   ram            p_cam             f_cam  \
# 149  Quad Core  1.4 GHz      16 GB  1 GB  8MP Rear Camera  5MP Front Camera
# 177  Quad Core  1.4 GHz      16 GB  1 GB  8MP Rear Camera  5MP Front Camera
# 298  Quad Core  1.4 GHz      16 GB  1 GB  8MP Rear Camera  5MP Front Camera
# 302  Quad Core  1.3 GHz       8 GB  1 GB  5MP Rear Camera  2MP Front Camera
#
#                   network battery_power mob_width mob_height mob_depth  \
# 149  3G, 4G VOLTE, 4G, 2G      3000 mAh   70.1 mm   140.4 mm   8.35 mm
# 177  3G, 4G VOLTE, 4G, 2G      3000 mAh   70.1 mm   140.4 mm   8.35 mm
# 298            4G, 3G, 2G      2600 mAh   72.1 mm   143.4 mm   8.95 mm
# 302            3G, 4G, 2G      2000 mAh     69 mm   136.5 mm    8.4 mm
#
#     mob_weight
# 149      137 g
# 177      137 g
# 298      154 g
# 302      130 g

# %%
df[df["num_cores"] == "Single Core"]
# Out:
#                 mobile_name mobile_price mobile_color            disp_size  \
# 435  OPPO F1S (Grey, 32 GB)        11990         Grey  13.97 cm (5.5 inch)
#
#      resolution                      os    num_cores mp_speed int_memory  \
# 435  720 x 1280  Android Lollipop 5.1.1  Single Core  1.5 GHz      32 GB
#
#       ram             p_cam              f_cam   network battery_power  \
# 435  3 GB  13MP Rear Camera  16MP Front Camera  4G VOLTE      3075 mAh
#
#     mob_width mob_height mob_depth mob_weight
# 435  154.5 mm    7.38 mm     76 mm      160 g

# %%
#there are some columns that have clear int value 
# so lets clean those columns and convert them to float or int
l = ["mp_speed","int_memory","ram","battery_power","mob_width","mob_height","mob_depth","mob_weight"]

for i in l:
    df[i] = df[i].str.replace("[a-zA-Z]","",regex=True)

# %%
df.head(3)
# Out:
#                           mobile_name mobile_price mobile_color  \
# 0  Realme Narzo 10A (So White, 32 GB)         8999     So White
# 1   Realme Narzo 10A (So Blue, 32 GB)         8999      So Blue
# 2   Realme Narzo 10A (So Blue, 64 GB)         9999      So Blue
#
#               disp_size         resolution          os  num_cores mp_speed  \
# 0  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2
# 1  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2
# 2  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2
#
#   int_memory ram             p_cam             f_cam               network  \
# 0        32   3   12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 1        32   3   12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 2        64   4   12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
#
#   battery_power mob_width mob_height mob_depth mob_weight
# 0         5000        75      164.4      8.95        195
# 1         5000        75      164.4      8.95        195
# 2         5000        75      164.4      8.95        195

# %%
#now lets convert the columns: float type to float and int type to int
df[["int_memory","ram","battery_power","mobile_price"]] = df[["int_memory","ram","battery_power","mobile_price"]].astype("int")
df[["mp_speed","mob_width","mob_height","mob_depth","mob_weight"]] = df[["mp_speed","mob_width","mob_height","mob_depth","mob_weight"]].astype("float")

# %%
#checking the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    459 non-null    object
#  1   mobile_price   459 non-null    int32
#  2   mobile_color   459 non-null    object
#  3   disp_size      459 non-null    object
#  4   resolution     459 non-null    object
#  5   os             459 non-null    object
#  6   num_cores      459 non-null    object
#  7   mp_speed       459 non-null    float64
#  8   int_memory     459 non-null    int32
#  9   ram            459 non-null    int32
#  10  p_cam          459 non-null    object
#  11  f_cam          459 non-null    object
#  12  network        459 non-null    object
#  13  battery_power  459 non-null    int32
#  14  mob_width      459 non-null    float64
#  15  mob_height     459 non-null    float64
#  16  mob_depth      459 non-null    float64
#  17  mob_weight     459 non-null    float64
# dtypes: float64(5), int32(4), object(9)
# memory usage: 57.5+ KB

# %%
#lets convert the disp size in cm or iches,
#but as the disp size is already defined we just need to extract and coonvert
df["disp_size_cm"] = df['disp_size'].str.replace(' cm .*',"",regex = True)

# %%
df.head(3)
# Out:
#                           mobile_name  mobile_price mobile_color  \
# 0  Realme Narzo 10A (So White, 32 GB)          8999     So White
# 1   Realme Narzo 10A (So Blue, 32 GB)          8999      So Blue
# 2   Realme Narzo 10A (So Blue, 64 GB)          9999      So Blue
#
#               disp_size         resolution          os  num_cores  mp_speed  \
# 0  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2.0
# 1  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2.0
# 2  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core       2.0
#
#    int_memory  ram             p_cam             f_cam               network  \
# 0          32    3  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 1          32    3  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 2          64    4  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
#
#    battery_power  mob_width  mob_height  mob_depth  mob_weight disp_size_cm
# 0           5000       75.0       164.4       8.95       195.0        16.56
# 1           5000       75.0       164.4       8.95       195.0        16.56
# 2           5000       75.0       164.4       8.95       195.0        16.56

# %%
df.drop("disp_size",axis = 1,inplace = True)

# %%
df["disp_size_cm"] = df['disp_size_cm'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    459 non-null    object
#  1   mobile_price   459 non-null    int32
#  2   mobile_color   459 non-null    object
#  3   resolution     459 non-null    object
#  4   os             459 non-null    object
#  5   num_cores      459 non-null    object
#  6   mp_speed       459 non-null    float64
#  7   int_memory     459 non-null    int32
#  8   ram            459 non-null    int32
#  9   p_cam          459 non-null    object
#  10  f_cam          459 non-null    object
#  11  network        459 non-null    object
#  12  battery_power  459 non-null    int32
#  13  mob_width      459 non-null    float64
#  14  mob_height     459 non-null    float64
#  15  mob_depth      459 non-null    float64
#  16  mob_weight     459 non-null    float64
#  17  disp_size_cm   459 non-null    float64
# dtypes: float64(6), int32(4), object(8)
# memory usage: 57.5+ KB

# %%
#chekcing the num_cores columns
df["num_cores"].value_counts()
# Out:
# Octa Core      444
# Quad Core       14
# Single Core      1
# Name: num_cores, dtype: int64

# %%
#checking the other spec for the mobile wth number of cores = single
df[df["num_cores"] == "Single Core"]
# Out:
#                 mobile_name  mobile_price mobile_color  resolution  \
# 435  OPPO F1S (Grey, 32 GB)         11990         Grey  720 x 1280
#
#                          os    num_cores  mp_speed  int_memory  ram  \
# 435  Android Lollipop 5.1.1  Single Core       1.5          32    3
#
#                 p_cam              f_cam   network  battery_power  mob_width  \
# 435  13MP Rear Camera  16MP Front Camera  4G VOLTE           3075      154.5
#
#      mob_height  mob_depth  mob_weight  disp_size_cm
# 435        7.38       76.0       160.0         13.97

# %%
df.drop((df[df["num_cores"] == "Single Core"]).index,inplace=True)

# %%
df["num_cores"].value_counts()
# Out:
# Octa Core    444
# Quad Core     14
# Name: num_cores, dtype: int64

# %%
#dictionary with num of core values
d = {"Octa Core": 8,"Quad Core": 4}

# %%
#applying the dictionary to the column values
df["core"] = df["num_cores"].apply(lambda x: d[x])

# %%
df["core"].value_counts()
# Out:
# 8    444
# 4     14
# Name: core, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 458
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    458 non-null    object
#  1   mobile_price   458 non-null    int32
#  2   mobile_color   458 non-null    object
#  3   resolution     458 non-null    object
#  4   os             458 non-null    object
#  5   num_cores      458 non-null    object
#  6   mp_speed       458 non-null    float64
#  7   int_memory     458 non-null    int32
#  8   ram            458 non-null    int32
#  9   p_cam          458 non-null    object
#  10  f_cam          458 non-null    object
#  11  network        458 non-null    object
#  12  battery_power  458 non-null    int32
#  13  mob_width      458 non-null    float64
#  14  mob_height     458 non-null    float64
#  15  mob_depth      458 non-null    float64
#  16  mob_weight     458 non-null    float64
#  17  disp_size_cm   458 non-null    float64
#  18  core           458 non-null    int64
# dtypes: float64(6), int32(4), int64(1), object(8)
# memory usage: 64.4+ KB

# %%
#droping the num_core col
df.drop("num_cores",axis=1,inplace=True)

# %%
#extracting the Brand names form mobile name columns
df["brand"] = df["mobile_name"].str.replace(' .*',"",regex=True)

# %%
df["brand"].value_counts()
# Out:
# Vivo       96
# Redmi      93
# OPPO       85
# Realme     79
# Infinix    36
# POCO       31
# Mi         20
# Samsung    17
# MI3         1
# Name: brand, dtype: int64

# %%
#the mobile name columns is not of any significance so removing it
df.drop("mobile_name",axis = 1,inplace = True)

# %%
df.head(3)
# Out:
#    mobile_price mobile_color         resolution          os  mp_speed  \
# 0          8999     So White  1600 x 720 Pixels  Android 10       2.0
# 1          8999      So Blue  1600 x 720 Pixels  Android 10       2.0
# 2          9999      So Blue  1600 x 720 Pixels  Android 10       2.0
#
#    int_memory  ram             p_cam             f_cam               network  \
# 0          32    3  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 1          32    3  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
# 2          64    4  12MP + 2MP + 2MP  5MP Front Camera  4G VOLTE, 4G, 3G, 2G
#
#    battery_power  mob_width  mob_height  mob_depth  mob_weight  disp_size_cm  \
# 0           5000       75.0       164.4       8.95       195.0         16.56
# 1           5000       75.0       164.4       8.95       195.0         16.56
# 2           5000       75.0       164.4       8.95       195.0         16.56
#
#    core   brand
# 0     8  Realme
# 1     8  Realme
# 2     8  Realme

# %%
df["mobile_color"].nunique()
# Out:
# 165

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(25,9))
sns.barplot(data=df,x="mobile_color",y="mobile_price")
plt.xticks(rotation=60)
plt.tight_layout()

# %%
new = [ 'brand','mobile_color', 'resolution', 'os', 'p_cam', 'f_cam', 'network', 'battery_power','mob_width', 'mob_height', 'mob_depth', 'mob_weight', 'disp_size_cm','core','mobile_price', 'mp_speed','int_memory', 'ram',]

# %%
df = df[new]

# %%
df.head(2)
# Out:
#     brand mobile_color         resolution          os             p_cam  \
# 0  Realme     So White  1600 x 720 Pixels  Android 10  12MP + 2MP + 2MP
# 1  Realme      So Blue  1600 x 720 Pixels  Android 10  12MP + 2MP + 2MP
#
#               f_cam               network  battery_power  mob_width  \
# 0  5MP Front Camera  4G VOLTE, 4G, 3G, 2G           5000       75.0
# 1  5MP Front Camera  4G VOLTE, 4G, 3G, 2G           5000       75.0
#
#    mob_height  mob_depth  mob_weight  disp_size_cm  core  mobile_price  \
# 0       164.4       8.95       195.0         16.56     8          8999
# 1       164.4       8.95       195.0         16.56     8          8999
#
#    mp_speed  int_memory  ram
# 0       2.0          32    3
# 1       2.0          32    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 458
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          458 non-null    object
#  1   mobile_color   458 non-null    object
#  2   resolution     458 non-null    object
#  3   os             458 non-null    object
#  4   p_cam          458 non-null    object
#  5   f_cam          458 non-null    object
#  6   network        458 non-null    object
#  7   battery_power  458 non-null    int32
#  8   mob_width      458 non-null    float64
#  9   mob_height     458 non-null    float64
#  10  mob_depth      458 non-null    float64
#  11  mob_weight     458 non-null    float64
#  12  disp_size_cm   458 non-null    float64
#  13  core           458 non-null    int64
#  14  mobile_price   458 non-null    int32
#  15  mp_speed       458 non-null    float64
#  16  int_memory     458 non-null    int32
#  17  ram            458 non-null    int32
# dtypes: float64(6), int32(4), int64(1), object(7)
# memory usage: 60.8+ KB

# %%
#lets see the brand name ones more
df["brand"].unique()  # here we can see a brand named "MI3" which is mis spelled
# Out:
# array(['Realme', 'Redmi', 'Mi', 'MI3', 'Vivo', 'Samsung', 'Infinix',
#        'POCO', 'OPPO'], dtype=object)

# %%
#correcting the misspelling
df["brand"] = df["brand"].str.replace("MI3","Mi")

# %%
#lets start with numerical columns and check out their distribution
n_features = ['battery_power', 'mob_width', 'mob_height', 'mob_depth','mob_weight', 'disp_size_cm']

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,10))
for i,f in enumerate(n_features,1):
    plt.subplot(3,2,i)
    sns.distplot(df[f])  
    plt.tight_layout()

# %%
n_features = ['battery_power', 'mob_width', 'mob_height', 'mob_depth','mob_weight', 'disp_size_cm']

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,10))
for i,f in enumerate(n_features,1):
    plt.subplot(3,2,i)
    sns.regplot(data = df,x = f,y="mobile_price")  
    plt.tight_layout()

# %%
#eliminating outliers from mob_width col
df.drop((df[(df["mob_width"]<20) | (df["mob_width"]>140)]).index,inplace = True)

# %%
#eliminating outliers from mob_height col
df.drop((df[df["mob_height"]<125]).index,inplace=True)

# %%
#eliminating outliers from mob_depth col
df.drop((df[df["mob_depth"]>60]).index,inplace = True)

# %%
#eliminating outliers from battery_power col
df.drop((df[(df["battery_power"]<3000) | (df["battery_power"]>5500)]).index,inplace = True)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,10))
for i,f in enumerate(n_features,1):
    plt.subplot(3,2,i)
    sns.regplot(data = df,x = f,y="mobile_price")  
    plt.tight_layout()

# %%
#slicing and storing the numerical into temporary dataframe
temp = df.iloc[:,7:]

# %%
#heatmap to check the corelation between all the num varibales
plt.figure(figsize=(12,7),dpi=70)
sns.heatmap(temp.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#sorting and storing all the corelation only corrosponding the mobile price column
s = temp.corr()["mobile_price"].sort_values()[:-1]

# %%
#ploting the sorted corelation
s.plot(kind = "bar",figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
df.head(3)
# Out:
#     brand mobile_color         resolution          os             p_cam  \
# 0  Realme     So White  1600 x 720 Pixels  Android 10  12MP + 2MP + 2MP
# 1  Realme      So Blue  1600 x 720 Pixels  Android 10  12MP + 2MP + 2MP
# 2  Realme      So Blue  1600 x 720 Pixels  Android 10  12MP + 2MP + 2MP
#
#               f_cam               network  battery_power  mob_width  \
# 0  5MP Front Camera  4G VOLTE, 4G, 3G, 2G           5000       75.0
# 1  5MP Front Camera  4G VOLTE, 4G, 3G, 2G           5000       75.0
# 2  5MP Front Camera  4G VOLTE, 4G, 3G, 2G           5000       75.0
#
#    mob_height  mob_depth  mob_weight  disp_size_cm  core  mobile_price  \
# 0       164.4       8.95       195.0         16.56     8          8999
# 1       164.4       8.95       195.0         16.56     8          8999
# 2       164.4       8.95       195.0         16.56     8          9999
#
#    mp_speed  int_memory  ram
# 0       2.0          32    3
# 1       2.0          32    3
# 2       2.0          64    4

# %%
#price distribution per brand
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.title("Barplot")
sns.barplot(data=df,x="brand",y="mobile_price")
plt.subplot(1,2,2)
plt.title("Countplot")
sns.countplot(data=df,x="brand")
# Out:
# <AxesSubplot:title={'center':'Countplot'}, xlabel='brand', ylabel='count'>

# %%
#got and error on the first attempt as some rows contain special symbols
#checking the data
df["resolution"].unique()
#some rows contain $ symbol
# Out:
# array(['1600 x 720 Pixels', '2340 x 1080 pixels', '2400 x 1080 Pixels',
#        '1080 x 2340 Pixels', '1080 x 2400 Pixels', '720 x 1600 Pixels',
#        '1560 x 720 pixels', '2400 × 1080 Pixels', '1520 x 720 pixels',
#        '1520 x 720 Pixels', '2400 x 1080 pixel', '1560 x 720 Pixels',
#        '2160 x 1080 Pixels', '1440 x 720 pixels', '2280 x 1080 pixels',
#        '2160 x 1080 pixels', '2340 x 1080 Pixel', '1920 x 1080 Pixels',
#        '1920 x 1080 pixels', '2400 x 1080 Pixel', '1280 x 720 pixels',
#        '1520 x 720$$pixel', '2400 x 1080$$pixel', '1280 x 720 Pixels',
#        '720 x 1544 pixels', '720 x 1544 Pixels', '2340 x 1080 Pixels',
#        '2316 x 1080 pixels', '2280 x 1080 Pixels', '1440 x 720 Pixels',
#        '1440 x 720 Pixel', '1520 x 720$$ pixels', '1520 x 720$pixels',
#        '1080 x 2160 pixels', '1500 x 720 pixels', '720 x 1440 Pixels',
#        '720*1440 Pixels', '1080 x 1920 Pixels', '720 x 1520 pixels',
#        '1080 x 2340 pixels', '720 x 1560 pixels'], dtype=object)

# %%
#cleaning the $ symbol 
df["resolution"] = df["resolution"].str.replace("$","")

# %%
df["resolution"] = df["resolution"].str.replace("*"," x ")

# %%
df["resolution"].unique()
# Out:
# array(['1600 x 720 Pixels', '2340 x 1080 pixels', '2400 x 1080 Pixels',
#        '1080 x 2340 Pixels', '1080 x 2400 Pixels', '720 x 1600 Pixels',
#        '1560 x 720 pixels', '2400 × 1080 Pixels', '1520 x 720 pixels',
#        '1520 x 720 Pixels', '2400 x 1080 pixel', '1560 x 720 Pixels',
#        '2160 x 1080 Pixels', '1440 x 720 pixels', '2280 x 1080 pixels',
#        '2160 x 1080 pixels', '2340 x 1080 Pixel', '1920 x 1080 Pixels',
#        '1920 x 1080 pixels', '2400 x 1080 Pixel', '1280 x 720 pixels',
#        '1520 x 720pixel', '2400 x 1080pixel', '1280 x 720 Pixels',
#        '720 x 1544 pixels', '720 x 1544 Pixels', '2340 x 1080 Pixels',
#        '2316 x 1080 pixels', '2280 x 1080 Pixels', '1440 x 720 Pixels',
#        '1440 x 720 Pixel', '1520 x 720pixels', '1080 x 2160 pixels',
#        '1500 x 720 pixels', '720 x 1440 Pixels', '1080 x 1920 Pixels',
#        '720 x 1520 pixels', '1080 x 2340 pixels', '720 x 1560 pixels'],
#       dtype=object)

# %%
#barplot of resolution and price
plt.figure(figsize=(18,6))
sns.barplot(data=df,x="resolution",y="mobile_price")
plt.xticks(rotation=60)
plt.tight_layout()

# %%
#lets check the relation between the resolution and display size
plt.figure(figsize=(18,6))
sns.barplot(data=df,x="resolution",y="disp_size_cm")
plt.xticks(rotation=60)
plt.tight_layout()

# %%
#scatter plot of display size and mobile prize
plt.figure(figsize=(16,4))
sns.regplot(data=df,x="disp_size_cm",y="mobile_price")
# Out:
# <AxesSubplot:xlabel='disp_size_cm', ylabel='mobile_price'>

# %%
#droping the resolution column
df.drop("resolution",axis = 1,inplace = True)

# %%
#checking the mobile color column
plt.figure(figsize=(18,10))
plt.subplot(2,1,1)
sns.countplot(data=df,x="mobile_color")
plt.xticks(rotation=90)
plt.subplot(2,1,2)
sns.barplot(data=df,x="mobile_color",y="mobile_price")
plt.xticks(rotation=90)
plt.tight_layout()

# %%
#checking the os column
plt.figure(figsize=(18,10))
plt.subplot(2,1,1)
sns.countplot(data=df,x="os")
plt.xticks(rotation=90)
plt.subplot(2,1,2)
sns.barplot(data=df,x="os",y="mobile_price")
plt.xticks(rotation=90)
plt.tight_layout()

#counts wise the top three os doesnot have high daviation on the price 
#where as in case of os such as 'android pie 10' and 'android oreo 8.1.0' the have very less count but the price daviation is very high.

# %%
df.head(3)
# Out:
#     brand mobile_color          os             p_cam             f_cam  \
# 0  Realme     So White  Android 10  12MP + 2MP + 2MP  5MP Front Camera
# 1  Realme      So Blue  Android 10  12MP + 2MP + 2MP  5MP Front Camera
# 2  Realme      So Blue  Android 10  12MP + 2MP + 2MP  5MP Front Camera
#
#                 network  battery_power  mob_width  mob_height  mob_depth  \
# 0  4G VOLTE, 4G, 3G, 2G           5000       75.0       164.4       8.95
# 1  4G VOLTE, 4G, 3G, 2G           5000       75.0       164.4       8.95
# 2  4G VOLTE, 4G, 3G, 2G           5000       75.0       164.4       8.95
#
#    mob_weight  disp_size_cm  core  mobile_price  mp_speed  int_memory  ram
# 0       195.0         16.56     8          8999       2.0          32    3
# 1       195.0         16.56     8          8999       2.0          32    3
# 2       195.0         16.56     8          9999       2.0          64    4

# %%
#converting the categorical col to cat codes

# %%
df['color_cat'] = df["mobile_color"].astype("category").cat.codes

# %%
df["brand_cat"] = df["brand"].astype("category").cat.codes

# %%
df["os_cat"] = df["os"].astype("category").cat.codes

# %%
df["p_cam"] = df["p_cam"].astype("category").cat.codes

# %%
df["f_cam"] = df["f_cam"].astype("category").cat.codes

# %%
df["network"] = df["network"].astype("category").cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 437 entries, 0 to 458
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          437 non-null    object
#  1   mobile_color   437 non-null    object
#  2   os             437 non-null    object
#  3   p_cam          437 non-null    int8
#  4   f_cam          437 non-null    int8
#  5   network        437 non-null    int8
#  6   battery_power  437 non-null    int32
#  7   mob_width      437 non-null    float64
#  8   mob_height     437 non-null    float64
#  9   mob_depth      437 non-null    float64
#  10  mob_weight     437 non-null    float64
#  11  disp_size_cm   437 non-null    float64
#  12  core           437 non-null    int64
#  13  mobile_price   437 non-null    int32
#  14  mp_speed       437 non-null    float64
#  15  int_memory     437 non-null    int32
#  16  ram            437 non-null    int32
#  17  color_cat      437 non-null    int16
#  18  brand_cat      437 non-null    int8
#  19  os_cat         437 non-null    int8
# dtypes: float64(6), int16(1), int32(4), int64(1), int8(5), object(3)
# memory usage: 47.4+ KB

# %%
#droping the categorical values
data = df.drop(['brand','mobile_color','os'],axis = 1)

# %%
data.columns
# Out:
# Index(['p_cam', 'f_cam', 'network', 'battery_power', 'mob_width', 'mob_height',
#        'mob_depth', 'mob_weight', 'disp_size_cm', 'core', 'mobile_price',
#        'mp_speed', 'int_memory', 'ram', 'color_cat', 'brand_cat', 'os_cat'],
#       dtype='object')

# %%
#data preprocessing on the numerical features
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
data[['battery_power', 'mob_width', 'mob_height','mob_depth', 'mob_weight', 'disp_size_cm', 'core','mp_speed', 'int_memory', 'ram']] = scale.fit_transform(data[['battery_power', 'mob_width', 'mob_height','mob_depth', 'mob_weight', 'disp_size_cm', 'core','mp_speed', 'int_memory', 'ram']])

# %%
data.head()
# Out:
#    p_cam  f_cam  network  battery_power  mob_width  mob_height  mob_depth  \
# 0      4     12       12       1.483946  -0.231467    1.328739   0.876055
# 1      4     12       12       1.483946  -0.231467    1.328739   0.876055
# 2      4     12       12       1.483946  -0.231467    1.328739   0.876055
# 3      4     12       12       1.483946  -0.231467    1.328739   0.876055
# 4     35      3       12       1.483946   0.066518    1.328739   0.970864
#
#    mob_weight  disp_size_cm      core  mobile_price  mp_speed  int_memory  \
# 0    0.814754      0.808705  0.153033          8999  -0.37408   -0.873741
# 1    0.814754      0.808705  0.153033          8999  -0.37408   -0.873741
# 2    0.814754      0.808705  0.153033          9999  -0.37408   -0.383908
# 3    0.814754      0.808705  0.153033          9999  -0.37408   -0.383908
# 4    1.039220      0.742751  0.153033         11999  -0.37408    0.595758
#
#         ram  color_cat  brand_cat  os_cat
# 0 -0.947584        130          4       0
# 1 -0.947584        129          4       0
# 2 -0.465518        129          4       0
# 3 -0.465518        130          4       0
# 4 -0.465518        146          4       0

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['battery_power', 'mob_width', 'mob_height','mob_depth', 'mob_weight', 'disp_size_cm', 'core','mp_speed', 'int_memory', 'ram']]
y = df["mobile_price"]

# %%
#splitng the columns
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state = 29)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
#predictng the values on both the train and test data
train_pred = lm.predict(xtrain)
test_pred = lm.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Evaluation of model witht only numerical features
train_rmse = np.sqrt(mean_squared_error(ytrain,train_pred))
train_r2 = r2_score(ytrain,train_pred)

test_rmse = np.sqrt(mean_squared_error(ytest,test_pred))
test_r2 = r2_score(ytest,test_pred)

print(f"Training RMSE: {train_rmse}")
print(f"Training R2: {train_r2}")
print(f"Testing RMSE: {test_rmse}")
print(f"Testing R2: {test_r2}")
# Out:
# Training RMSE: 4553.280456133978
# Training R2: 0.7123817702178403
# Testing RMSE: 5336.915789126213
# Testing R2: 0.7063416931679807

# %%
data["mobile_price"].describe()
# Out:
# count      437.000000
# mean     16914.185355
# std       8792.164551
# min       6499.000000
# 25%      10999.000000
# 50%      14990.000000
# 75%      18990.000000
# max      60990.000000
# Name: mobile_price, dtype: float64

# %%
x = data.drop("mobile_price",axis = 1)
y = data["mobile_price"]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state = 29)

# %%
lm = LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
train_pred = lm.predict(xtrain)
test_pred = lm.predict(xtest)

# %%
# Evaluation of model with all the features involved
train_rmse = np.sqrt(mean_squared_error(ytrain,train_pred))
train_r2 = r2_score(ytrain,train_pred)

test_rmse = np.sqrt(mean_squared_error(ytest,test_pred))
test_r2 = r2_score(ytest,test_pred)

print(f"Training RMSE: {train_rmse}")
print(f"Training R2: {train_r2}")
print(f"Testing RMSE: {test_rmse}")
print(f"Testing R2: {test_r2}")
# Out:
# Training RMSE: 4428.054601933572
# Training R2: 0.7279845690052792
# Testing RMSE: 5343.139324120173
# Testing R2: 0.7056564065994798

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state = 109)

# %%
lm = LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
train_pred = lm.predict(xtrain)
test_pred = lm.predict(xtest)

# %%
# evaluation of model after changing the random_state
train_rmse = np.sqrt(mean_squared_error(ytrain,train_pred))
train_r2 = r2_score(ytrain,train_pred)

test_rmse = np.sqrt(mean_squared_error(ytest,test_pred))
test_r2 = r2_score(ytest,test_pred)

print(f"Training RMSE: {train_rmse}")
print(f"Training R2: {train_r2}")
print(f"Testing RMSE: {test_rmse}")
print(f"Testing R2: {test_r2}")
# Out:
# Training RMSE: 4544.6221646004615
# Training R2: 0.7264705307901573
# Testing RMSE: 4795.027859512504
# Testing R2: 0.7234571480836777
